# %% [markdown]
# ### Short range ###

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_short_range_5000_1_vx.pkl", "rb") as file:
    ot_solutions, ot_scores, mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)

ref_min = np.min(ot_scores[:,:-1])
ref_max = np.max(np.min(ot_scores[:,:-1], axis=1))+np.min([np.max(ot_scores[:,:-1]), np.max(np.min(ot_scores[:,:-1], axis=0))-ref_min])
output_string = f"\\renewcommand*{{\minval}}{{{ref_min:.1f}}}\n\\renewcommand*{{\maxval}}{{{ref_max:.1f}}}\n\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n$\\mu$"
for i in range(len(noise_level_subset)):
    output_string += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
output_string += "\\\\\n\hline\n\hline"
for i in range(len(mu_values)-1):
    output_string += f"\n{mu_values[i]:.0e}"
    for j in range(len(noise_level_subset)):
        output_string += f" & \gradient{{{ot_scores[j,i]:.1f}}}"
    output_string += "\\\\\n\hline"
output_string += f"\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(output_string)
# Out:
# \renewcommand*{\minval}{11.3}
# \renewcommand*{\maxval}{27.7}
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
# $\mu$ & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# 5e-05 & \gradient{13.6} & \gradient{28.8} & \gradient{32.8} & \gradient{35.9} & \gradient{39.0}\\
# \hline
# 1e-04 & \gradient{11.8} & \gradient{25.7} & \gradient{31.6} & \gradient{35.1} & \gradient{38.0}\\
# \hline
# 2e-04 & \gradient{11.3} & \gradient{22.8} & \gradient{29.4} & \gradient{33.3} & \gradient{37.1}\\
# \hline
# 5e-04 & \gradient{13.7} & \gradient{17.6} & \gradient{23.5} & \gradient{28.1} & \gradient{32.1}\\
# \hline
# 1e-03 & \gradient{20.5} & \gradient{16.5} & \gradient{20.5} & \gradient{25.1} & \gradient{27.5}\\
# \hline
# 2e-03 & \gradient{20.4} & \gradient{19.4} & \gradient{21.3} & \gradient{24.0} & \gradient{26.6}\\
# \hline
# 5e-03 & \gradient{20.8} & \gradient{19.1} & \gradient{20.4} & \gradient{22.6} & \gradient{25.3}\\
# \hline
# ...

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_short_range_5000_1_g50.pkl", "rb") as file:
    ot_solutions, ot_scores, mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)

ref_min = np.min(ot_scores[:,:-1])
ref_max = np.max(np.min(ot_scores[:,:-1], axis=1))+np.min([np.max(ot_scores[:,:-1]), np.max(np.min(ot_scores[:,:-1], axis=0))-ref_min])
output_string = f"\\renewcommand*{{\minval}}{{{ref_min:.1f}}}\n\\renewcommand*{{\maxval}}{{{ref_max:.1f}}}\n\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n$\\mu$"
for i in range(len(noise_level_subset)):
    output_string += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
output_string += "\\\\\n\hline\n\hline"
for i in range(len(mu_values)-1):
    output_string += f"\n{mu_values[i]:.0e}"
    for j in range(len(noise_level_subset)):
        output_string += f" & \gradient{{{ot_scores[j,i]:.1f}}}"
    output_string += "\\\\\n\hline"
output_string += f"\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(output_string)
# Out:
# \renewcommand*{\minval}{11.2}
# \renewcommand*{\maxval}{27.8}
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
# $\mu$ & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# 5e-05 & \gradient{16.0} & \gradient{28.5} & \gradient{32.2} & \gradient{35.2} & \gradient{38.0}\\
# \hline
# 1e-04 & \gradient{12.5} & \gradient{26.1} & \gradient{31.3} & \gradient{34.8} & \gradient{37.7}\\
# \hline
# 2e-04 & \gradient{11.2} & \gradient{21.0} & \gradient{28.8} & \gradient{33.4} & \gradient{37.1}\\
# \hline
# 5e-04 & \gradient{13.8} & \gradient{16.0} & \gradient{21.2} & \gradient{26.9} & \gradient{31.7}\\
# \hline
# 1e-03 & \gradient{20.5} & \gradient{16.5} & \gradient{18.5} & \gradient{22.6} & \gradient{26.8}\\
# \hline
# 2e-03 & \gradient{20.4} & \gradient{19.4} & \gradient{21.3} & \gradient{22.8} & \gradient{23.4}\\
# \hline
# 5e-03 & \gradient{20.8} & \gradient{19.1} & \gradient{20.4} & \gradient{22.6} & \gradient{25.3}\\
# \hline
# ...

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_short_range_5000_1_str.pkl", "rb") as file:
    ot_solutions, ot_scores, mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)

ref_min = np.min(ot_scores[:,:-1])
ref_max = np.max(np.min(ot_scores[:,:-1], axis=1))+np.min([np.max(ot_scores[:,:-1]), np.max(np.min(ot_scores[:,:-1], axis=0))-ref_min])
output_string = f"\\renewcommand*{{\minval}}{{{ref_min:.1f}}}\n\\renewcommand*{{\maxval}}{{{ref_max:.1f}}}\n\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n$\\mu$"
for i in range(len(noise_level_subset)):
    output_string += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
output_string += "\\\\\n\hline\n\hline"
for i in range(len(mu_values)-1):
    output_string += f"\n{mu_values[i]:.0e}"
    for j in range(len(noise_level_subset)):
        output_string += f" & \gradient{{{ot_scores[j,i]:.1f}}}"
    output_string += "\\\\\n\hline"
output_string += f"\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(output_string)
# Out:
# \renewcommand*{\minval}{21.1}
# \renewcommand*{\maxval}{34.8}
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
# $\mu$ & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# 5e-05 & \gradient{27.2} & \gradient{33.0} & \gradient{37.7} & \gradient{41.4} & \gradient{44.0}\\
# \hline
# 1e-04 & \gradient{27.2} & \gradient{32.9} & \gradient{37.6} & \gradient{41.4} & \gradient{43.9}\\
# \hline
# 2e-04 & \gradient{27.2} & \gradient{32.9} & \gradient{37.6} & \gradient{41.3} & \gradient{43.9}\\
# \hline
# 5e-04 & \gradient{27.1} & \gradient{32.8} & \gradient{37.5} & \gradient{41.1} & \gradient{43.8}\\
# \hline
# 1e-03 & \gradient{27.0} & \gradient{32.7} & \gradient{37.4} & \gradient{40.8} & \gradient{43.6}\\
# \hline
# 2e-03 & \gradient{26.8} & \gradient{32.8} & \gradient{37.3} & \gradient{40.6} & \gradient{43.3}\\
# \hline
# 5e-03 & \gradient{26.5} & \gradient{32.6} & \gradient{37.0} & \gradient{40.4} & \gradient{43.1}\\
# \hline
# ...

# %% [markdown]
# ### Long range ###

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_long_range_5000_1.pkl", "rb") as file:
    ot_solutions, ot_scores, mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)

ref_min = np.min(ot_scores[:,:-1])
ref_max = np.max(np.min(ot_scores[:,:-1], axis=1))+np.min([np.max(ot_scores[:,:-1]), np.max(np.min(ot_scores[:,:-1], axis=0))-ref_min])
output_string = f"\\renewcommand*{{\minval}}{{{ref_min:.1f}}}\n\\renewcommand*{{\maxval}}{{{ref_max:.1f}}}\n\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n$\\mu$"
for i in range(len(noise_level_subset)):
    output_string += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
output_string += "\\\\\n\hline\n\hline"
for i in range(len(mu_values)-1):
    output_string += f"\n{mu_values[i]:.0e}"
    for j in range(len(noise_level_subset)):
        output_string += f" & \gradient{{{ot_scores[j,i]:.1f}}}"
    output_string += "\\\\\n\hline"
output_string += f"\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(output_string)
# Out:
# \renewcommand*{\minval}{11.3}
# \renewcommand*{\maxval}{27.7}
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
# $\mu$ & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# 5e-05 & \gradient{13.6} & \gradient{28.8} & \gradient{32.8} & \gradient{35.9} & \gradient{39.0}\\
# \hline
# 1e-04 & \gradient{11.8} & \gradient{25.7} & \gradient{31.6} & \gradient{35.1} & \gradient{38.0}\\
# \hline
# 2e-04 & \gradient{11.3} & \gradient{22.8} & \gradient{29.4} & \gradient{33.3} & \gradient{37.1}\\
# \hline
# 5e-04 & \gradient{13.7} & \gradient{17.6} & \gradient{23.5} & \gradient{28.1} & \gradient{32.1}\\
# \hline
# 1e-03 & \gradient{20.5} & \gradient{16.5} & \gradient{20.5} & \gradient{25.1} & \gradient{27.5}\\
# \hline
# 2e-03 & \gradient{20.4} & \gradient{19.4} & \gradient{21.3} & \gradient{24.0} & \gradient{26.6}\\
# \hline
# 5e-03 & \gradient{20.8} & \gradient{19.1} & \gradient{20.4} & \gradient{22.6} & \gradient{25.3}\\
# \hline
# ...

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_short_range_5000_1_g50.pkl", "rb") as file:
    ot_solutions, ot_scores, mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)

ref_min = np.min(ot_scores[:,:-1])
ref_max = np.max(np.min(ot_scores[:,:-1], axis=1))+np.min([np.max(ot_scores[:,:-1]), np.max(np.min(ot_scores[:,:-1], axis=0))-ref_min])
output_string = f"\\renewcommand*{{\minval}}{{{ref_min:.1f}}}\n\\renewcommand*{{\maxval}}{{{ref_max:.1f}}}\n\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n$\\mu$"
for i in range(len(noise_level_subset)):
    output_string += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
output_string += "\\\\\n\hline\n\hline"
for i in range(len(mu_values)-1):
    output_string += f"\n{mu_values[i]:.0e}"
    for j in range(len(noise_level_subset)):
        output_string += f" & \gradient{{{ot_scores[j,i]:.1f}}}"
    output_string += "\\\\\n\hline"
output_string += f"\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(output_string)

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_short_range_5000_1_str.pkl", "rb") as file:
    ot_solutions, ot_scores, mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)

ref_min = np.min(ot_scores[:,:-1])
ref_max = np.max(np.min(ot_scores[:,:-1], axis=1))+np.min([np.max(ot_scores[:,:-1]), np.max(np.min(ot_scores[:,:-1], axis=0))-ref_min])
output_string = f"\\renewcommand*{{\minval}}{{{ref_min:.1f}}}\n\\renewcommand*{{\maxval}}{{{ref_max:.1f}}}\n\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n$\\mu$"
for i in range(len(noise_level_subset)):
    output_string += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
output_string += "\\\\\n\hline\n\hline"
for i in range(len(mu_values)-1):
    output_string += f"\n{mu_values[i]:.0e}"
    for j in range(len(noise_level_subset)):
        output_string += f" & \gradient{{{ot_scores[j,i]:.1f}}}"
    output_string += "\\\\\n\hline"
output_string += f"\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(output_string)
# Out:
# \renewcommand*{\minval}{21.1}
# \renewcommand*{\maxval}{34.8}
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
# $\mu$ & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# 5e-05 & \gradient{27.2} & \gradient{33.0} & \gradient{37.7} & \gradient{41.4} & \gradient{44.0}\\
# \hline
# 1e-04 & \gradient{27.2} & \gradient{32.9} & \gradient{37.6} & \gradient{41.4} & \gradient{43.9}\\
# \hline
# 2e-04 & \gradient{27.2} & \gradient{32.9} & \gradient{37.6} & \gradient{41.3} & \gradient{43.9}\\
# \hline
# 5e-04 & \gradient{27.1} & \gradient{32.8} & \gradient{37.5} & \gradient{41.1} & \gradient{43.8}\\
# \hline
# 1e-03 & \gradient{27.0} & \gradient{32.7} & \gradient{37.4} & \gradient{40.8} & \gradient{43.6}\\
# \hline
# 2e-03 & \gradient{26.8} & \gradient{32.8} & \gradient{37.3} & \gradient{40.6} & \gradient{43.3}\\
# \hline
# 5e-03 & \gradient{26.5} & \gradient{32.6} & \gradient{37.0} & \gradient{40.4} & \gradient{43.1}\\
# \hline
# ...

# %% [markdown]
# ### Aggregation table short problem ###

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_short_range_5000_1_vx.pkl", "rb") as file:
    ot_solutions, ot_scores, ot_mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/mu_short_range_5000_1_g50.pkl", "rb") as file:
    uot_solutions, uot_scores, uot_mu_values, noise_level_subset = pickle.load(file)
    uot_solutions = np.array(uot_solutions)
    uot_scores = np.array(uot_scores)
with open("small_example/lambda_experiments/mu_short_range_5000_1_str.pkl", "rb") as file:
    str_solutions, str_scores, str_mu_values, noise_level_subset = pickle.load(file)
    str_solutions = np.array(str_solutions)
    str_scores = np.array(str_scores)
with open("small_example/lambda_experiments/bench_short_range_5000_1_nonneg.pkl", "rb") as file:
    mce_solutions, mce_scores, cmce_solutions, cmce_scores, _, _ = pickle.load(file)
    mce_solutions = np.array(mce_solutions)
    mce_scores = np.array(mce_scores)
    cmce_solutions = np.array(cmce_solutions)
    cmce_scores = np.array(cmce_scores)
with open("small_example/lambda_experiments/short_range_5000_1.pkl", "rb") as file:
    lambda_values, noise_levels = pickle.load(file)
    lambda_values = np.array(lambda_values)

ot_indices = np.argmin(ot_scores, axis=1)
uot_indices = np.argmin(uot_scores, axis=1)
str_indices = np.argmin(str_scores, axis=1)

best_ot_mu = [ot_mu_values[i] for i in ot_indices]
best_uot_mu = [uot_mu_values[i] for i in uot_indices]
best_str_mu = [str_mu_values[i] for i in str_indices]

best_ot_score = np.min(ot_scores, axis=1)
best_uot_score = np.min(uot_scores, axis=1)
best_str_score = np.min(str_scores, axis=1)

out = f"\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n"
for i in range(len(noise_level_subset)):
    out += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
out += "\\\\\n\hline\n\hline\n"
out += "EMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {best_ot_score[i]:.1f}"
out += "\\\\\n\hline\nuEMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {best_uot_score[i]:.1f}"
out += "\\\\\n\hline\nMCE"
for i in range(len(noise_level_subset)):
    out += f" & {mce_scores[i]:.1f}"
out += "\\\\\n\hline\ncMCE"
for i in range(len(noise_level_subset)):
    out += f" & {cmce_scores[i]:.1f}"
out += "\\\\\n\hline\nNORM\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {best_str_score[i]:.1f}"
out += "\\\\\n\hline\n\hline\n$\lambda$"
for i in range(len(noise_level_subset)):
    out += f" & {lambda_values[noise_level_subset[i],-1]:.2e}"
out += "\\\\\n\hline\n$\mu_\\text{EMD}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_ot_mu[i]:.0e}"
out += "\\\\\n\hline\n$\mu_\\text{uEMD}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_uot_mu[i]:.0e}"
out += "\\\\\n\hline\n$\mu_\\text{STR}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_str_mu[i]:.0e}"
out += f"\\\\\n\hline\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(out)
# Out:
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
#  & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# EMD\_STR & 11.3 & 16.5 & 17.4 & 18.5 & 19.0\\
# \hline
# uEMD\_STR & 11.2 & 16.0 & 17.4 & 18.5 & 19.1\\
# \hline
# MCE & 27.2 & 33.0 & 37.7 & 41.4 & 44.0\\
# \hline
# cMCE & 16.7 & 17.7 & 19.6 & 21.3 & 23.0\\
# \hline
# NORM\_STR & 21.1 & 23.6 & 25.3 & 26.6 & 28.1\\
# \hline
# \hline
# $\lambda$ & 2.87e-03 & 1.24e-02 & 2.21e-02 & 3.21e-02 & 4.20e-02\\
# \hline
# $\mu_\text{EMD}$ & 2e-04 & 1e-03 & 2e-01 & 1e-01 & 5e-02\\
# \hline
# $\mu_\text{uEMD}$ & 2e-04 & 5e-04 & 2e-01 & 5e-02 & 5e-02\\
# \hline
# $\mu_\text{STR}$ & 2e-01 & 2e+00 & 5e+00 & 2e+01 & 2e+01\\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %%
from dipoles import Dipoles
from inverse_problem import InverseProblem

with open("small_example/short_range_problem.pkl", "rb") as file:
    inverse_problem = pickle.load(file)
grid = Dipoles.from_txt(f"text_files/half_grid_5000.txt")

ot_distances = np.zeros(ot_solutions.shape[2])
for i in range(ot_solutions.shape[2]):
    ot_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], ot_solutions[:,:,i,ot_indices[i]], mute=True)[0]
uot_distances = np.zeros(uot_solutions.shape[2])
for i in range(uot_solutions.shape[2]):
    uot_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], uot_solutions[:,:,i,uot_indices[i]], mute=True)[0]
str_distances = np.zeros(ot_solutions.shape[2])
for i in range(str_solutions.shape[2]):
    str_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], str_solutions[:,:,i,str_indices[i]], mute=True)[0]
mce_distances = np.zeros(mce_solutions.shape[2])
cmce_distances = np.zeros(mce_solutions.shape[2])
for i in range(mce_solutions.shape[2]):
    mce_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], mce_solutions[:,:,i], mute=True)[0]
    cmce_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], cmce_solutions[:,:,i], mute=True)[0]

out = f"\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n"
for i in range(len(noise_level_subset)):
    out += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
out += "\\\\\n\hline\n\hline\n"
out += "EMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {ot_distances[i]:.1f}"
out += "\\\\\n\hline\nuEMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {uot_distances[i]:.1f}"
out += "\\\\\n\hline\nMCE"
for i in range(len(noise_level_subset)):
    out += f" & {mce_distances[i]:.1f}"
out += "\\\\\n\hline\ncMCE"
for i in range(len(noise_level_subset)):
    out += f" & {cmce_distances[i]:.1f}"
out += "\\\\\n\hline\nNORM\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {str_distances[i]:.1f}"
out += f"\\\\\n\hline\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(out)
# Out:
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
#  & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# EMD\_STR & 0.7 & 12.2 & 13.0 & 13.4 & 12.1\\
# \hline
# uEMD\_STR & 0.7 & 12.2 & 13.0 & 12.1 & 12.1\\
# \hline
# MCE & 12.3 & 23.1 & 23.1 & 23.1 & 23.1\\
# \hline
# cMCE & 12.2 & 12.7 & 13.0 & 13.0 & 13.0\\
# \hline
# NORM\_STR & 9.8 & 9.8 & 9.8 & 13.0 & 13.0\\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %% [markdown]
# ### Aggregation table long problem ###

# %%
import numpy as np
import pickle


with open("small_example/lambda_experiments/mu_long_range_5000_1.pkl", "rb") as file:
    ot_solutions, ot_scores, ot_mu_values, noise_level_subset = pickle.load(file)
    ot_solutions = np.array(ot_solutions)
    ot_scores = np.array(ot_scores)
with open("small_example/lambda_experiments/mu_long_range_5000_1_g50.pkl", "rb") as file:
    uot_solutions, uot_scores, uot_mu_values, noise_level_subset = pickle.load(file)
    uot_solutions = np.array(uot_solutions)
    uot_scores = np.array(uot_scores)
with open("small_example/lambda_experiments/mu_long_range_5000_1_str.pkl", "rb") as file:
    str_solutions, str_scores, str_mu_values, noise_level_subset = pickle.load(file)
    str_solutions = np.array(str_solutions)
    str_scores = np.array(str_scores)
with open("small_example/lambda_experiments/mu_long_range_5000_1_g50_noconnect.pkl", "rb") as file:
    noc_solutions, noc_scores, noc_mu_values, noise_level_subset = pickle.load(file)
    noc_solutions = np.array(noc_solutions)
    noc_scores = np.array(noc_scores)
with open("small_example/lambda_experiments/bench_long_range_5000_1_nonneg.pkl", "rb") as file:
    mce_solutions, mce_scores, cmce_solutions, cmce_scores, _, _ = pickle.load(file)
    mce_solutions = np.array(mce_solutions)
    mce_scores = np.array(mce_scores)
    cmce_solutions = np.array(cmce_solutions)
    cmce_scores = np.array(cmce_scores)
with open("small_example/lambda_experiments/long_range_5000_1.pkl", "rb") as file:
    lambda_values, noise_levels = pickle.load(file)
    lambda_values = np.array(lambda_values)

ot_indices = np.argmin(ot_scores, axis=1)
uot_indices = np.argmin(uot_scores, axis=1)
str_indices = np.argmin(str_scores, axis=1)
noc_indices = np.argmin(noc_scores, axis=1)

best_ot_mu = [ot_mu_values[i] for i in ot_indices]
best_uot_mu = [uot_mu_values[i] for i in uot_indices]
best_str_mu = [str_mu_values[i] for i in str_indices]
best_noc_mu = [noc_mu_values[i] for i in noc_indices]

best_ot_score = np.min(ot_scores, axis=1)
best_uot_score = np.min(uot_scores, axis=1)
best_str_score = np.min(str_scores, axis=1)
best_noc_score = np.min(noc_scores, axis=1)

out = f"\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n"
for i in range(len(noise_level_subset)):
    out += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
out += "\\\\\n\hline\n\hline\n"
out += "EMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {best_ot_score[i]:.1f}"
out += "\\\\\n\hline\nuEMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {best_uot_score[i]:.1f}"
out += "\\\\\n\hline\nMCE"
for i in range(len(noise_level_subset)):
    out += f" & {mce_scores[i]:.1f}"
out += "\\\\\n\hline\ncMCE"
for i in range(len(noise_level_subset)):
    out += f" & {cmce_scores[i]:.1f}"
out += "\\\\\n\hline\nNORM\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {best_str_score[i]:.1f}"
out += "\\\\\n\hline\nNOCON"
for i in range(len(noise_level_subset)):
    out += f" & {best_noc_score[i]:.1f}"
out += "\\\\\n\hline\n\hline\n$\lambda$"
for i in range(len(noise_level_subset)):
    out += f" & {lambda_values[noise_level_subset[i]]:.2e}"
out += "\\\\\n\hline\n$\mu_\\text{EMD}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_ot_mu[i]:.0e}"
out += "\\\\\n\hline\n$\mu_\\text{uEMD}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_uot_mu[i]:.0e}"
out += "\\\\\n\hline\n$\mu_\\text{STR}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_str_mu[i]:.0e}"
out += "\\\\\n\hline\n$\mu_\\text{NOC}$"
for i in range(len(noise_level_subset)):
    out += f" & {best_noc_mu[i]:.0e}"
out += f"\\\\\n\hline\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(out)
# Out:
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
#  & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# EMD\_STR & 18.9 & 10.7 & 6.0 & 4.1 & 2.3\\
# \hline
# uEMD\_STR & 6.9 & 7.6 & 6.1 & 4.1 & 2.4\\
# \hline
# MCE & 20.9 & 21.7 & 25.2 & 28.0 & 29.9\\
# \hline
# cMCE & 65.1 & 63.6 & 62.1 & 60.4 & 57.9\\
# \hline
# NORM\_STR & 20.7 & 20.0 & 21.0 & 21.8 & 22.3\\
# \hline
# NOCONNECT & 20.4 & 18.5 & 18.7 & 18.7 & 18.9\\
# \hline
# \hline
# $\lambda$ & 1.30e-02 & 5.96e-02 & 1.08e-01 & 1.72e-01 & 2.55e-01\\
# \hline
# $\mu_\text{EMD}$ & 2e-03 & 1e-02 & 1e-02 & 2e-02 & 2e-02\\
# \hline
# $\mu_\text{uEMD}$ & 2e-03 & 5e-03 & 1e-02 & 2e-02 & 2e-02\\
# \hline
# $\mu_\text{STR}$ & 1e-01 & 5e-01 & 2e+00 & 5e+00 & 1e+01\\
# \hline
# $\mu_\text{NOC}$ & 2e-04 & 2e-04 & 5e-04 & 5e-04 & 5e-04\\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %%
from dipoles import Dipoles
from inverse_problem import InverseProblem

with open("small_example/long_range_problem.pkl", "rb") as file:
    inverse_problem = pickle.load(file)
grid = Dipoles.from_txt(f"text_files/half_grid_5000.txt")

ot_distances = np.zeros(ot_solutions.shape[2])
for i in range(ot_solutions.shape[2]):
    ot_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], ot_solutions[:,:,i,ot_indices[i]], mute=True)[5]
uot_distances = np.zeros(uot_solutions.shape[2])
for i in range(uot_solutions.shape[2]):
    uot_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], uot_solutions[:,:,i,uot_indices[i]], mute=True)[5]
str_distances = np.zeros(ot_solutions.shape[2])
for i in range(str_solutions.shape[2]):
    str_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], str_solutions[:,:,i,str_indices[i]], mute=True)[5]
noc_distances = np.zeros(ot_solutions.shape[2])
for i in range(noc_solutions.shape[2]):
    noc_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], noc_solutions[:,:,i,noc_indices[i]], mute=True)[5]
mce_distances = np.zeros(mce_solutions.shape[2])
cmce_distances = np.zeros(mce_solutions.shape[2])
for i in range(mce_solutions.shape[2]):
    mce_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], mce_solutions[:,:,i], mute=True)[5]
    cmce_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], cmce_solutions[:,:,i], mute=True)[5]

out = f"\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n"
for i in range(len(noise_level_subset)):
    out += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
out += "\\\\\n\hline\n\hline\n"
out += "EMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {ot_distances[i]:.1f}"
out += "\\\\\n\hline\nuEMD\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {uot_distances[i]:.1f}"
out += "\\\\\n\hline\nMCE"
for i in range(len(noise_level_subset)):
    out += f" & {mce_distances[i]:.1f}"
out += "\\\\\n\hline\ncMCE"
for i in range(len(noise_level_subset)):
    out += f" & {cmce_distances[i]:.1f}"
out += "\\\\\n\hline\nNORM\\_STR"
for i in range(len(noise_level_subset)):
    out += f" & {str_distances[i]:.1f}"
out += "\\\\\n\hline\nNOCON"
for i in range(len(noise_level_subset)):
    out += f" & {noc_distances[i]:.1f}"
out += f"\\\\\n\hline\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(out)
# Out:
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
#  & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# EMD\_STR & 0.7 & 0.7 & 0.7 & 0.7 & 0.7\\
# \hline
# uEMD\_STR & 0.7 & 0.7 & 0.7 & 0.7 & 0.7\\
# \hline
# MCE & 12.1 & 13.2 & 13.2 & 25.0 & 25.0\\
# \hline
# cMCE & 103.3 & 103.3 & 12.7 & 12.7 & 103.3\\
# \hline
# NORM\_STR & 12.1 & 12.1 & 12.1 & 12.8 & 12.8\\
# \hline
# NOCON & 12.1 & 12.1 & 25.1 & 25.1 & 25.1\\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %% [markdown]
# ### ADMM ###

# %%
import pickle
import numpy as np
from inverse_problem import InverseProblem
from dipoles import Dipoles

iteration_cutoff = 23
with open(f"small_example/lambda_experiments/admm_short_range_5000_1_g50.pkl", "rb") as file:
    admm_solutions, admm_scores, _, _, _, iteration_numbers, noise_level_subset = pickle.load(file)
    admm_solutions = np.array(admm_solutions)[iteration_cutoff-1,:,:,:]
    admm_scores = np.array(admm_scores)[iteration_cutoff-1,:]
    # primal_residuals = np.array(primal_residuals)
    # dual_residuals = np.array(dual_residuals)
    # relative_errors = np.array(relative_errors)
with open("small_example/lambda_experiments/short_range_5000_1_nonneg.pkl", "rb") as file:
    _, noise_levels = pickle.load(file)
with open("small_example/short_range_problem.pkl", "rb") as file:
    inverse_problem = pickle.load(file)
grid = Dipoles.from_txt(f"text_files/half_grid_5000.txt")

admm_distances = np.zeros(admm_solutions.shape[2])
for i in range(admm_solutions.shape[2]):
    admm_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], admm_solutions[:,:,i], mute=True)[0]

out = f"\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{{len(noise_level_subset)+1}}}{{|c|}}}}\n\hline\n"
for i in range(len(noise_level_subset)):
    out += f" & {noise_levels[noise_level_subset[i]]*100:.0f}\% noise"
out += "\\\\\n\hline\n\hline\n"
out += "Short range EMD"
for i in range(len(noise_level_subset)):
    out += f" & {admm_scores[i]:.1f}"
out += "\\\\\n\hline\nShort range DLE"
for i in range(len(noise_level_subset)):
    out += f" & {admm_distances[i]:.1f}"
out += "\\\\\n\hline"

with open(f"small_example/lambda_experiments/admm_long_range_5000_1_g50.pkl", "rb") as file:
    admm_solutions, admm_scores, _, _, _, iteration_numbers, noise_level_subset = pickle.load(file)
    admm_solutions = np.array(admm_solutions)[iteration_cutoff-1,:,:,:]
    admm_scores = np.array(admm_scores)[iteration_cutoff-1,:]
with open("small_example/long_range_problem.pkl", "rb") as file:
    inverse_problem = pickle.load(file)

admm_distances = np.zeros(admm_solutions.shape[2])
for i in range(admm_solutions.shape[2]):
    admm_distances[i] = inverse_problem.evaluate_solution_dist(grid.dipoles[:,:3], admm_solutions[:,:,i], mute=True)[5]

out += "\n\hline\nLong range EMD"
for i in range(len(noise_level_subset)):
    out += f" & {admm_scores[i]:.1f}"
out += "\\\\\n\hline\nLong range DLE"
for i in range(len(noise_level_subset)):
    out += f" & {admm_distances[i]:.1f}"
out += f"\\\\\n\hline\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(out)
# Out:
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{6}{|c|}}
# \hline
#  & 2\% noise & 8\% noise & 14\% noise & 20\% noise & 26\% noise\\
# \hline
# \hline
# Short range EMD & 12.3 & 14.7 & 18.3 & 17.9 & 18.4\\
# \hline
# Short range DLE & 6.0 & 12.2 & 13.0 & 13.0 & 13.0\\
# \hline
# \hline
# Long range EMD & 14.4 & 15.7 & 13.9 & 16.4 & 18.7\\
# \hline
# Long range DLE & 0.7 & 12.1 & 0.7 & 0.7 & 0.7\\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %% [markdown]
# ### Timings ###

# %%
import numpy as np
import pickle

with open(f"small_example/lambda_experiments/time_5000_3.pkl", "rb") as file:
    mosek_times_short, cvxpy_times_short, mosek_times_long, cvxpy_times_long = pickle.load(file)
with open(f"small_example/lambda_experiments/time_admm_5000_3.pkl", "rb") as file:
    admm_times_short, admm_times_long = pickle.load(file)

out = f"\\begin{{table}}[ht]\n\\begin{{center}}\n\\begin{{tabular}}{{*{{3}}{{|c|}}}}\n\hline\n"
out += "Method & Short range example time & Long range example time\\\\\n"
out += "\hline\n"
out += f"uEMD with MOSEK & {np.mean(mosek_times_short)/60:.1f} & {np.mean(mosek_times_long)/60:.1f}\\\\\n"
out += "\hline\n"
out += f"uEMD with CVXPY & {np.mean(cvxpy_times_short)/60:.1f} & {np.mean(cvxpy_times_long)/60:.1f}\\\\\n"
out += "\hline\n"
out += f"ADMM & {np.mean(admm_times_short)/60:.1f} & {np.mean(admm_times_long)/60:.1f}\\\\\n"
out += f"\hline\n\end{{tabular}}\n\end{{center}}\n\end{{table}}"
print(out)
# Out:
# \begin{table}[ht]
# \begin{center}
# \begin{tabular}{*{3}{|c|}}
# \hline
# Method & Short range example time & Long range example time\\
# \hline
# uEMD with MOSEK & 0.6 & 3.8\\
# \hline
# uEMD with CVXPY & 13.9 & 189.6\\
# \hline
# ADMM & 4.4 & 15.8\\
# \hline
# \end{tabular}
# \end{center}
# \end{table}
